# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jinhyeongpark/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()

api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
from newsapi.newsapi_client import NewsApiClient

newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='relevancy',
                                     )

# %%
# Fetch the Ethereum news articles
eth_articles = newsapi.get_everything(q='ethereum',
                                      language='en',
                                      sort_by='relevancy',
                                      )

# %%
# Create the DataFrame
def get_sentiment_score(article, based_on):
    sentiments = []
    for article in article["articles"]:
        try:
            text = article[based_on]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sentiments.append({
                "Compound": compound,
                "Negative": neg,
                "Neutral": neu,
                "Positive": pos,
                "text" : text
            })
        except AttributeError:
            pass
    # Create DataFrame
    df = pd.DataFrame(sentiments)
    return df

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_df = get_sentiment_score(btc_articles, 'content')
btc_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.0000       0.0    1.000     0.000
# 1    0.5106       0.0    0.901     0.099
# 2    0.0000       0.0    1.000     0.000
# 3    0.5719       0.0    0.847     0.153
# 4    0.4767       0.0    0.864     0.136
#
#                                                 text
# 0  The plant opening northeast of Niagara Falls t...
# 1  Earlier this year, Nothing released a pair of ...
# 2  MIZATA, El Salvador/LONDON, Nov 22 (Reuters) -...
# 3  In keeping with a previous announcement, AMC t...
# 4  Posted \r\nAfter becoming the first country to...

# %%
# Create the Ethereum sentiment scores DataFrame
eth_df = get_sentiment_score(eth_articles, 'content')
eth_df.head(5)
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7783     0.000    0.784     0.216
# 1    0.0000     0.000    1.000     0.000
# 2    0.5719     0.000    0.847     0.153
# 3    0.6542     0.000    0.822     0.178
# 4   -0.0516     0.079    0.847     0.074
#
#                                                 text
# 0  If you claim ownership, someone will probably ...
# 1  More than $1.2 million has already been spent ...
# 2  In keeping with a previous announcement, AMC t...
# 3  Ethereum has been on a tear this year. Its out...
# 4  Blockchain startup MonoX Finance said on Wedne...

# %%
# Describe the Bitcoin Sentiment
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Sentiment scores dictionaries
btc_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.099135   0.016200   0.939900   0.043900
# std     0.305228   0.029573   0.068112   0.065594
# min    -0.381800   0.000000   0.791000   0.000000
# 25%     0.000000   0.000000   0.891750   0.000000
# 50%     0.000000   0.000000   0.957000   0.000000
# 75%     0.463275   0.010750   1.000000   0.108250
# max     0.571900   0.080000   1.000000   0.158000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#        Compound  Negative    Neutral   Positive
# count  20.00000  20.00000  20.000000  20.000000
# mean    0.21461   0.02620   0.898450   0.075250
# std     0.29546   0.03871   0.078875   0.065669
# min    -0.31820   0.00000   0.729000   0.000000
# 25%     0.00000   0.00000   0.844000   0.000000
# 50%     0.17635   0.00000   0.910500   0.072000
# 75%     0.42490   0.06200   0.955500   0.113000
# max     0.77830   0.11500   1.000000   0.216000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: ETH 0.07525
#
# Q: Which coin had the highest compound score?
#
# A: 0.77830
#
# Q. Which coin had the highest positive score?
#
# A: ETH 0.216

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))


# Expand the default stopwords list if necessary

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words = word_tokenize(re_clean.lower())
    
    # Lemmatize words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    words = [word for word in words if word not in sw]
    
    # Remove the stop words
    # There are none
    
    return tokens
# tokenizer(btc_df.iloc[0]['content'])

# %%
# Create a new tokens column for Bitcoin
btc_df['tokens'] = btc_df['text'].apply(tokenizer)
btc_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.0000     0.000    1.000     0.000
# 1     0.5106     0.000    0.901     0.099
# 2     0.0000     0.000    1.000     0.000
# 3     0.5719     0.000    0.847     0.153
# 4     0.4767     0.000    0.864     0.136
# 5     0.1280     0.000    0.957     0.043
# 6     0.0000     0.000    1.000     0.000
# 7     0.0000     0.000    1.000     0.000
# 8    -0.3818     0.080    0.920     0.000
# 9    -0.1027     0.043    0.957     0.000
# 10    0.5106     0.000    0.842     0.158
# 11    0.5106     0.000    0.858     0.142
# 12   -0.3818     0.077    0.923     0.000
# 13    0.0000     0.000    1.000     0.000
# 14   -0.3182     0.062    0.938     0.000
# 15    0.0000     0.000    1.000     0.000
# 16    0.4588     0.062    0.791     0.147
# 17    0.0000     0.000    1.000     0.000
# 18    0.0000     0.000    1.000     0.000
# 19    0.0000     0.000    1.000     0.000
#
#                                                  text  \
# 0   The plant opening northeast of Niagara Falls t...
# 1   Earlier this year, Nothing released a pair of ...
# 2   MIZATA, El Salvador/LONDON, Nov 22 (Reuters) -...
# 3   In keeping with a previous announcement, AMC t...
# 4   Posted \r\nAfter becoming the first country to...
# 5   Available for the same price, $99, on December...
# 6   (Reuters) - A computer scientist who has claim...
# 7   Spotify has removed the shuffle button from al...
# 8   Dec 4 (Reuters) - Bitcoin dropped 8.4% to $49,...
# 9   Australian Baseball League club Perth Heat wil...
# 10  Posted \r\nBitcoin shed a fifth of its value o...
# 11  Posted \r\nBitcoin shed a fifth of its value o...
# 12  Dec 3 (Reuters) - Bitcoin plunged 5.5% to $53,...
# 13  A representation of the virtual cryptocurrency...
# 14  Bitcoin tumbled almost 5% on Monday as the sta...
# 15  Posted \r\nEl Salvador plans to build the worl...
# 16  In a disclosure that should surprise no one, t...
# 17  Posted \r\nA computer scientist who has claime...
# 18  Posted \r\nA computer scientist who has claime...
# 19  Representations of the virtual currency Bitcoi...
#
#                                                tokens
# 0   [the, plant, opening, northeast, of, niagara, ...
# 1   [earlier, this, year, nothing, released, a, pa...
# 2   [mizata, el, salvadorlondon, nov, 22, reuters,...
# 3   [in, keeping, with, a, previous, announcement,...
# 4   [posted, after, becoming, the, first, country,...
# 5   [available, for, the, same, price, 99, on, dec...
# 6   [reuters, a, computer, scientist, who, ha, cla...
# 7   [spotify, ha, removed, the, shuffle, button, f...
# 8   [dec, 4, reuters, bitcoin, dropped, 84, to, 49...
# 9   [australian, baseball, league, club, perth, he...
# 10  [posted, bitcoin, shed, a, fifth, of, it, valu...
# 11  [posted, bitcoin, shed, a, fifth, of, it, valu...
# 12  [dec, 3, reuters, bitcoin, plunged, 55, to, 53...
# 13  [a, representation, of, the, virtual, cryptocu...
# 14  [bitcoin, tumbled, almost, 5, on, monday, a, t...
# 15  [posted, el, salvador, plan, to, build, the, w...
# 16  [in, a, disclosure, that, should, surprise, no...
# 17  [posted, a, computer, scientist, who, ha, clai...
# 18  [posted, a, computer, scientist, who, ha, clai...
# 19  [representation, of, the, virtual, currency, b...

# %%
# Create a new tokens column for Ethereum
eth_df['tokens'] = eth_df['text'].apply(tokenizer)
eth_df
# Out:
#     Compound  Negative  Neutral  Positive  \
# 0     0.7783     0.000    0.784     0.216
# 1     0.0000     0.000    1.000     0.000
# 2     0.5719     0.000    0.847     0.153
# 3     0.6542     0.000    0.822     0.178
# 4    -0.0516     0.079    0.847     0.074
# 5    -0.1531     0.045    0.955     0.000
# 6     0.5106     0.000    0.901     0.099
# 7     0.4939     0.000    0.881     0.119
# 8     0.0000     0.000    1.000     0.000
# 9     0.3818     0.000    0.920     0.080
# 10    0.3612     0.000    0.930     0.070
# 11    0.4019     0.115    0.729     0.155
# 12    0.2732     0.075    0.814     0.111
# 13   -0.0418     0.086    0.835     0.079
# 14    0.1280     0.000    0.957     0.043
# 15   -0.3182     0.062    0.938     0.000
# 16    0.0000     0.000    1.000     0.000
# 17    0.2247     0.000    0.942     0.058
# 18    0.0772     0.062    0.867     0.070
# 19    0.0000     0.000    1.000     0.000
#
#                                                  text  \
# 0   If you claim ownership, someone will probably ...
# 1   More than $1.2 million has already been spent ...
# 2   In keeping with a previous announcement, AMC t...
# 3   Ethereum has been on a tear this year. Its out...
# 4   Blockchain startup MonoX Finance said on Wedne...
# 5   On Monday, Budweiser joined the non-fungible t...
# 6   Earlier this year, Nothing released a pair of ...
# 7   Nicholas Merten , an expert in cryptography, p...
# 8   White Castle double cheeseburger.Erin McDowell...
# 9   Regal movie theater.Shutterstock\r\nMovie-thea...
# 10  While people around the world still searched f...
# 11  The wait is finally over. After a year-long de...
# 12  MicroStrategy CEO Michael SaylorJoe Raedle/Get...
# 13  The Fine Print: The following comments are own...
# 14  Available for the same price, $99, on December...
# 15  Bitcoin has lost almost 20 per cent in less th...
# 16  Decentralized finance or DeFi is a global fina...
# 17  The U.S. Captioning Company and the British In...
# 18  Image source, Getty Images\r\nImage caption, T...
# 19  Hours ago, a website appeared online with the ...
#
#                                                tokens
# 0   [if, you, claim, ownership, someone, will, pro...
# 1   [more, than, 12, million, ha, already, been, s...
# 2   [in, keeping, with, a, previous, announcement,...
# 3   [ethereum, ha, been, on, a, tear, this, year, ...
# 4   [blockchain, startup, monox, finance, said, on...
# 5   [on, monday, budweiser, joined, the, nonfungib...
# 6   [earlier, this, year, nothing, released, a, pa...
# 7   [nicholas, merten, an, expert, in, cryptograph...
# 8   [white, castle, double, cheeseburgererin, mcdo...
# 9   [regal, movie, theatershutterstockmovietheater...
# 10  [while, people, around, the, world, still, sea...
# 11  [the, wait, is, finally, over, after, a, yearl...
# 12  [microstrategy, ceo, michael, saylorjoe, raedl...
# 13  [the, fine, print, the, following, comment, ar...
# 14  [available, for, the, same, price, 99, on, dec...
# 15  [bitcoin, ha, lost, almost, 20, per, cent, in,...
# 16  [decentralized, finance, or, defi, is, a, glob...
# 17  [the, u, captioning, company, and, the, britis...
# 18  [image, source, getty, imagesimage, caption, t...
# 19  [hour, ago, a, website, appeared, online, with...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
def get_token(df):
    tokens = []
    for i in df['tokens']:
        tokens.extend(i)
    return tokens

btc_tokens = get_token(btc_df)
eth_tokens = get_token(eth_df)

def bigram_counter(tokens, N):
    words_count = dict(Counter(ngrams(tokens, n=N)))
    return words_count


bigram_btc = bigram_counter(btc_tokens, 2)
bigram_btc
# Out:
# {('the', 'plant'): 1,
#  ('plant', 'opening'): 1,
#  ('opening', 'northeast'): 1,
#  ('northeast', 'of'): 1,
#  ('of', 'niagara'): 1,
#  ('niagara', 'fall'): 1,
#  ('fall', 'this'): 1,
#  ('this', 'month'): 1,
#  ('month', 'in'): 1,
#  ('in', 'somerset'): 1,
#  ('somerset', 'ny'): 1,
#  ('ny', 'is'): 1,
#  ('is', 'part'): 1,
#  ('part', 'of'): 1,
#  ('of', 'a'): 6,
#  ('a', '550'): 1,
#  ('550', 'million'): 1,
#  ('million', 'project'): 1,
#  ('project', 'by'): 1,
#  ('by', 'terawulf'): 1,
#  ('terawulf', 'a'): 1,
#  ('a', 'bitcoin'): 1,
#  ('bitcoin', 'mining'): 1,
#  ('mining', 'company'): 1,
#  ('company', 'the'): 1,
#  ('the', 'project'): 1,
#  ('project', 'also'): 1,
#  ('also', 'includes'): 1,
#  ('includes', 'a'): 1,
#  ('a', 'proposed'): 1,
#  ('proposed', '150megawatt'): 1,
#  ('150megawatt', '1514'): 1,
#  ('1514', 'char'): 1,
#  ('char', 'earlier'): 1,
#  ('earlier', 'this'): 2,
#  ('this', 'year'): 2,
#  ('year', 'nothing'): 1,
#  ('nothing', 'released'): 1,
#  ('released', 'a'): 1,
#  ('a', 'pair'): 1,
#  ('pair', 'of'): 1,
#  ('of', 'relatively'): 1,
#  ('relatively', 'cheap'): 1,
#  ('cheap', '99'): 1,
#  ('99', 'ear'): 1,
#  ('ear', '1'): 3,
#  ('1', 'earbuds'): 3,
#  ('earbuds', 'with'): 1,
#  ('with', 'a'): 3,
#  ('a', 'fun'): 1,
#  ('fun', 'transparent'): 1,
#  ('transparent', 'case'): 1,
#  ('case', 'wireless'): 1,
#  ('wireless', 'charging'): 1,
#  ('charging', 'and'): 1,
#  ('and', 'decent'): 1,
#  ('decent', 'sound'): 1,
#  ('sound', 'quality'): 1,
#  ('quality', 'now'): 1,
#  ('now', 'the'): 1,
#  ('the', 'company'): 2,
#  ('company', 'created'): 1,
#  ('created', 'by'): 1,
#  ('by', 'oneplus'): 1,
#  ('oneplus', 'cofounde'): 1,
#  ('cofounde', '1395'): 1,
#  ('1395', 'char'): 1,
#  ('char', 'mizata'): 1,
#  ('mizata', 'el'): 1,
#  ('el', 'salvadorlondon'): 1,
#  ('salvadorlondon', 'nov'): 1,
#  ('nov', '22'): 1,
#  ('22', 'reuters'): 1,
#  ('reuters', 'el'): 1,
#  ('el', 'salvador'): 3,
#  ('salvador', 'plan'): 3,
#  ('plan', 'to'): 3,
#  ('to', 'build'): 3,
#  ('build', 'the'): 3,
#  ('the', 'world'): 6,
#  ('world', 'first'): 4,
#  ('first', 'bitcoin'): 3,
#  ('bitcoin', 'city'): 3,
#  ('city', 'with'): 2,
#  ('with', 'money'): 2,
#  ('money', 'from'): 2,
#  ('from', 'a'): 2,
#  ('a', '1'): 2,
#  ('1', 'billion'): 2,
#  ('billion', 'bitcoinbacked'): 2,
#  ('bitcoinbacked', 'bond'): 3,
#  ('bond', 'the'): 1,
#  ('the', 'country'): 2,
#  ('country', 'president'): 2,
#  ('president', 'nayib'): 2,
#  ('nayib', 'bukele'): 2,
#  ('bukele', 'said'): 1,
#  ('said', 'o'): 1,
#  ('o', '3147'): 1,
#  ('3147', 'char'): 1,
#  ('char', 'in'): 2,
#  ('in', 'keeping'): 1,
#  ('keeping', 'with'): 1,
#  ('a', 'previous'): 1,
#  ('previous', 'announcement'): 1,
#  ('announcement', 'amc'): 1,
#  ('amc', 'theater'): 1,
#  ('theater', 'now'): 1,
#  ('now', 'accept'): 1,
#  ('accept', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'a'): 1,
#  ('a', 'payment'): 1,
#  ('payment', 'for'): 1,
#  ('for', 'online'): 1,
#  ('online', 'purchasesbitcoin'): 1,
#  ('purchasesbitcoin', 'ethereum'): 1,
#  ('ethereum', 'bitcoin'): 1,
#  ('bitcoin', 'cash'): 1,
#  ('cash', 'and'): 1,
#  ('and', 'litecoin'): 1,
#  ('litecoin', 'are'): 1,
#  ('are', 'acceptedpreviously'): 1,
#  ('acceptedpreviously', 'the'): 1,
#  ('the', 'compa'): 1,
#  ('compa', '1036'): 1,
#  ('1036', 'char'): 1,
#  ('char', 'posted'): 5,
#  ('posted', 'after'): 1,
#  ('after', 'becoming'): 1,
#  ('becoming', 'the'): 1,
#  ('the', 'first'): 1,
#  ('first', 'country'): 1,
#  ('country', 'to'): 1,
#  ('to', 'accept'): 1,
#  ('accept', 'the'): 1,
#  ('the', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'a'): 1,
#  ('a', 'legal'): 1,
#  ('legal', 'tender'): 1,
#  ('tender', 'el'): 1,
#  ('city', 'funded'): 1,
#  ('funded', 'initially'): 1,
#  ('initially', 'by'): 1,
#  ('by', 'bitcoinbacked'): 1,
#  ('bond', 'available'): 1,
#  ('available', 'for'): 1,
#  ('for', 'the'): 3,
#  ('the', 'same'): 1,
#  ('same', 'price'): 1,
#  ('price', '99'): 1,
#  ('99', 'on'): 1,
#  ('on', 'december'): 1,
#  ('december', '13ththe'): 1,
#  ('13ththe', 'ear'): 1,
#  ('earbuds', 'and'): 1,
#  ('and', 'case'): 1,
#  ('case', 'now'): 1,
#  ('now', 'in'): 1,
#  ('in', 'blackimage'): 1,
#  ('blackimage', 'nothingnothings'): 1,
#  ('nothingnothings', 'ear'): 1,
#  ('earbuds', 'which'): 1,
#  ('which', 'launched'): 1,
#  ('launched', 'earlier'): 1,
#  ('year', 'in'): 1,
#  ('in', 'a'): 6,
#  ('a', 'fetching'): 1,
#  ('fetching', 'white'): 1,
#  ('white', 'and'): 1,
#  ('and', 'transp'): 1,
#  ('transp', '1865'): 1,
#  ('1865', 'char'): 1,
#  ('char', 'reuters'): 1,
#  ('reuters', 'a'): 1,
#  ('a', 'computer'): 3,
#  ('computer', 'scientist'): 3,
#  ('scientist', 'who'): 3,
#  ('who', 'ha'): 3,
#  ('ha', 'claimed'): 3,
#  ('claimed', 'to'): 3,
#  ('to', 'be'): 4,
#  ('be', 'the'): 3,
#  ('the', 'inventor'): 3,
#  ('inventor', 'of'): 3,
#  ('of', 'bitcoin'): 3,
#  ('bitcoin', 'largely'): 3,
#  ('largely', 'prevailed'): 3,
#  ('prevailed', 'on'): 1,
#  ('on', 'monday'): 2,
#  ('monday', 'in'): 1,
#  ('a', 'florida'): 3,
#  ('florida', 'jury'): 3,
#  ('jury', 'trial'): 3,
#  ('trial', 'over'): 3,
#  ('over', 'whether'): 3,
#  ('whether', 'the'): 3,
#  ('the', 'estate'): 3,
#  ('estate', 'of'): 3,
#  ('a', 'former'): 3,
#  ('former', 'business'): 3,
#  ('business', 'partner'): 3,
#  ('partner', 'deserved'): 3,
#  ('deserved', 'half'): 3,
#  ('half', 'o'): 1,
#  ('o', '1785'): 1,
#  ('1785', 'char'): 1,
#  ('char', 'spotify'): 1,
#  ('spotify', 'ha'): 1,
#  ('ha', 'removed'): 1,
#  ('removed', 'the'): 1,
#  ('the', 'shuffle'): 1,
#  ('shuffle', 'button'): 1,
#  ('button', 'from'): 1,
#  ('from', 'all'): 1,
#  ('all', 'album'): 1,
#  ('album', 'page'): 1,
#  ('page', 'after'): 1,
#  ('after', 'adele'): 1,
#  ('adele', 'pressed'): 1,
#  ('pressed', 'the'): 1,
#  ('company', 'for'): 1,
#  ('the', 'change'): 1,
#  ('change', 'in'): 1,
#  ('in', 'time'): 1,
#  ('time', 'for'): 1,
#  ('the', 'launch'): 1,
#  ('launch', 'of'): 1,
#  ('of', 'her'): 1,
#  ('her', 'album'): 1,
#  ('album', '30'): 1,
#  ('30', 'according'): 1,
#  ('according', 'to'): 2,
#  ('to', 'her'): 1,
#  ('her', 'own'): 1,
#  ('own', 'tweet'): 1,
#  ('tweet', 'album'): 1,
#  ('album', 'should'): 1,
#  ('should', 'be'): 1,
#  ('be', 'liste'): 1,
#  ('liste', '3186'): 1,
#  ('3186', 'char'): 1,
#  ('char', 'dec'): 2,
#  ('dec', '4'): 1,
#  ('4', 'reuters'): 2,
#  ('reuters', 'bitcoin'): 4,
#  ('bitcoin', 'dropped'): 2,
#  ('dropped', '84'): 1,
#  ('84', 'to'): 1,
#  ('to', '4922882'): 1,
#  ('4922882', 'at'): 1,
#  ('at', '2001'): 1,
#  ('2001', 'gmt'): 1,
#  ('gmt', 'on'): 2,
#  ('on', 'saturday'): 3,
#  ('saturday', 'losing'): 1,
#  ('losing', '451487'): 1,
#  ('451487', 'from'): 1,
#  ('from', 'it'): 2,
#  ('it', 'previous'): 2,
#  ('previous', 'closebitcoin'): 2,
#  ('closebitcoin', 'the'): 2,
#  ('world', 'biggest'): 2,
#  ('biggest', 'and'): 2,
#  ('and', 'bestknown'): 2,
#  ('bestknown', 'cryptocurrency'): 2,
#  ('cryptocurrency', 'is'): 2,
#  ('is', 'down'): 2,
#  ('down', '287'): 1,
#  ('287', 'fro'): 1,
#  ('fro', '355'): 1,
#  ('355', 'char'): 1,
#  ('char', 'australian'): 1,
#  ('australian', 'baseball'): 1,
#  ('baseball', 'league'): 1,
#  ('league', 'club'): 1,
#  ('club', 'perth'): 1,
#  ('perth', 'heat'): 1,
#  ('heat', 'will'): 1,
#  ('will', 'pay'): 1,
#  ('pay', 'it'): 1,
#  ('it', 'player'): 1,
#  ('player', 'in'): 1,
#  ('in', 'bitcoin'): 1,
#  ('bitcoin', 'after'): 1,
#  ('after', 'partnering'): 1,
#  ('partnering', 'with'): 1,
#  ('a', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'payment'): 1,
#  ('payment', 'company'): 1,
#  ('company', 'in'): 1,
#  ('a', 'deal'): 1,
#  ('deal', 'it'): 1,
#  ('it', 'claim'): 1,
#  ('claim', 'to'): 1,
#  ('be', 'a'): 1,
#  ('a', 'world'): 1,
#  ('first', 'for'): 1,
#  ('for', 'professional'): 1,
#  ('professional', 'sporthea'): 1,
#  ('sporthea', '2695'): 1,
#  ('2695', 'char'): 1,
#  ('posted', 'bitcoin'): 2,
#  ('bitcoin', 'shed'): 2,
#  ('shed', 'a'): 2,
#  ('a', 'fifth'): 3,
#  ('fifth', 'of'): 3,
#  ('of', 'it'): 3,
#  ('it', 'value'): 3,
#  ('value', 'on'): 2,
#  ('saturday', 'a'): 2,
#  ('a', 'a'): 2,
#  ('a', 'combination'): 2,
#  ('combination', 'of'): 2,
#  ('of', 'profittaking'): 2,
#  ('profittaking', 'and'): 2,
#  ('and', 'macroeconomic'): 2,
#  ('macroeconomic', 'concern'): 2,
#  ('concern', 'triggered'): 2,
#  ('triggered', 'nearly'): 2,
#  ('nearly', 'a'): 2,
#  ('a', 'billion'): 2,
#  ('billion', 'dollar'): 2,
#  ('dollar', 'worth'): 2,
#  ('worth', 'of'): 2,
#  ('of', 'selling'): 2,
#  ('selling', 'across'): 2,
#  ('across', 'cryptocurrencies'): 2,
#  ('cryptocurrencies', 'posted'): 1,
#  ('cryptocurrencies', 'fred'): 1,
#  ('fred', '16'): 1,
#  ('16', 'char'): 1,
#  ('dec', '3'): 1,
#  ('3', 'reuters'): 1,
#  ('bitcoin', 'plunged'): 1,
#  ('plunged', '55'): 1,
#  ('55', 'to'): 1,
#  ('to', '534359'): 1,
#  ('534359', 'at'): 1,
#  ('at', '2204'): 1,
#  ('2204', 'gmt'): 1,
#  ('on', 'friday'): 1,
#  ('friday', 'losing'): 1,
#  ('losing', '311206'): 1,
#  ('311206', 'from'): 1,
#  ('down', '226'): 1,
#  ('226', 'from'): 1,
#  ('from', 't'): 1,
#  ('t', '350'): 1,
#  ('350', 'char'): 1,
#  ('char', 'a'): 1,
#  ('a', 'representation'): 1,
#  ('representation', 'of'): 2,
#  ('of', 'the'): 3,
#  ('the', 'virtual'): 2,
#  ('virtual', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'bitcoin'): 1,
#  ('bitcoin', 'is'): 1,
#  ('is', 'seen'): 1,
#  ('seen', 'in'): 1,
#  ('in', 'this'): 2,
#  ('this', 'picture'): 2,
#  ('picture', 'illustration'): 2,
#  ('illustration', 'taken'): 2,
#  ('taken', 'october'): 1,
#  ('october', '19'): 1,
#  ('19', '2021'): 1,
#  ('2021', 'reutersedgar'): 1,
#  ('reutersedgar', 'sudec'): 1,
#  ('sudec', '4'): 1,
#  ('dropped', '929'): 1,
#  ('929', 'to'): 1,
#  ('to', '4875215'): 1,
#  ('4875215', 'at'): 1,
#  ('at', '2201'): 1,
#  ('2201', 'gmt'): 1,
#  ('gmt', '489'): 1,
#  ('489', 'char'): 1,
#  ('char', 'bitcoin'): 1,
#  ('bitcoin', 'tumbled'): 1,
#  ('tumbled', 'almost'): 1,
#  ('almost', '5'): 1,
#  ('5', 'on'): 1,
#  ('monday', 'a'): 1,
#  ('a', 'the'): 1,
#  ('the', 'start'): 1,
#  ('start', 'of'): 1,
#  ('the', 'week'): 1,
#  ('week', 'offered'): 1,
#  ('offered', 'little'): 1,
#  ('little', 'respite'): 1,
#  ('respite', 'to'): 1,
#  ('to', 'the'): 2,
#  ('world', 'largest'): 1,
#  ('largest', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'after'): 1,
#  ('after', 'a'): 1,
#  ('a', 'bruising'): 1,
#  ('bruising', 'weekend'): 1,
#  ('weekend', 'where'): 1,
#  ('where', 'at'): 1,
#  ('at', 'one'): 1,
#  ('one', 'point'): 1,
#  ('point', 'it'): 1,
#  ('it', 'lost'): 1,
#  ('lost', 'over'): 1,
#  ('over', 'a'): 1,
#  ('value', '2615'): 1,
#  ('2615', 'char'): 1,
#  ('posted', 'el'): 1,
#  ('bond', 'according'): 1,
#  ('bukele', 'here'): 1,
#  ('here', 'is'): 1,
#  ('is', 'what'): 1,
#  ('what', 'we'): 1,
#  ('we', 'know'): 1,
#  ('know', 'about'): 1,
#  ('about', 'th'): 1,
#  ('th', '92'): 1,
#  ('92', 'char'): 1,
#  ('a', 'disclosure'): 1,
#  ('disclosure', 'that'): 1,
#  ('that', 'should'): 1,
#  ('should', 'surprise'): 1,
#  ('surprise', 'no'): 1,
#  ('no', 'one'): 1,
#  ('one', 'the'): 1,
#  ('the', 'head'): 1,
#  ('head', 'honcho'): 1,
#  ('honcho', 'at'): 1,
#  ('at', 'the'): 1,
#  ('the', 'cia'): 1,
#  ('cia', 'ha'): 1,
#  ('ha', 'confirmed'): 1,
#  ('confirmed', 'that'): 1,
#  ('that', 'the'): 1,
#  ('the', 'intelligence'): 1,
#  ('intelligence', 'agency'): 1,
#  ('agency', 'ha'): 1,
#  ('ha', 'multiple'): 1,
#  ('multiple', 'project'): 1,
#  ('project', 'related'): 1,
#  ('related', 'to'): 1,
#  ('to', 'cryptocurrencyrumorsoften'): 1,
#  ('cryptocurrencyrumorsoften', 'not'): 1,
#  ('not', 'entirely'): 1,
#  ('entirely', 'seriousha'): 1,
#  ('seriousha', '4310'): 1,
#  ('4310', 'char'): 1,
#  ('posted', 'a'): 2,
#  ('prevailed', 'this'): 2,
#  ('this', 'week'): 2,
#  ('week', 'in'): 2,
#  ('half', 'of'): 2,
#  ('a', '70'): 2,
#  ('70', 'char'): 2,
#  ('char', 'representation'): 1,
#  ('virtual', 'currency'): 1,
#  ('currency', 'bitcoin'): 1,
#  ('bitcoin', 'stand'): 1,
#  ('stand', 'on'): 1,
#  ('on', 'a'): 1,
#  ('a', 'motherboard'): 1,
#  ('motherboard', 'in'): 1,
#  ('taken', 'may'): 1,
#  ('may', '20'): 1,
#  ('20', '2021'): 1,
#  ('2021', 'reutersdado'): 1,
#  ('reutersdado', 'ruvicfile'): 1,
#  ('ruvicfile', 'photolondon'): 1,
#  ('photolondon', 'nov'): 1,
#  ('nov', '16'): 1,
#  ('16', 'reuters'): 1,
#  ('bitcoin', 'fell'): 1,
#  ('fell', 'below'): 1,
#  ('below', '60'): 1,
#  ('60', '629'): 1,
#  ('629', 'char'): 1}

# %%
# Generate the Ethereum N-grams where N=2
bigram_eth = bigram_counter(eth_tokens, 2)
bigram_eth
# Out:
# {('if', 'you'): 1,
#  ('you', 'claim'): 1,
#  ('claim', 'ownership'): 1,
#  ('ownership', 'someone'): 1,
#  ('someone', 'will'): 1,
#  ('will', 'probably'): 1,
#  ('probably', 'want'): 1,
#  ('want', 'to'): 1,
#  ('to', 'take'): 1,
#  ('take', 'itin'): 1,
#  ('itin', 'what'): 1,
#  ('what', 'may'): 1,
#  ('may', 'be'): 1,
#  ('be', 'one'): 1,
#  ('one', 'of'): 1,
#  ('of', 'the'): 5,
#  ('the', 'better'): 1,
#  ('better', 'piece'): 1,
#  ('piece', 'of'): 2,
#  ('of', 'performance'): 1,
#  ('performance', 'art'): 1,
#  ('art', 'this'): 1,
#  ('this', 'year'): 5,
#  ('year', 'australian'): 1,
#  ('australian', 'geoffrey'): 1,
#  ('geoffrey', 'huntley'): 1,
#  ('huntley', 'ha'): 1,
#  ('ha', 'created'): 1,
#  ('created', 'a'): 1,
#  ('a', 'website'): 2,
#  ('website', 'that'): 1,
#  ('that', 'promise'): 1,
#  ('promise', 'to'): 1,
#  ('to', '4542'): 1,
#  ('4542', 'char'): 1,
#  ('char', 'more'): 1,
#  ('more', 'than'): 2,
#  ('than', '12'): 1,
#  ('12', 'million'): 1,
#  ('million', 'ha'): 1,
#  ('ha', 'already'): 1,
#  ('already', 'been'): 1,
#  ('been', 'spent'): 1,
#  ('spent', 'on'): 1,
#  ('on', 'gas'): 1,
#  ('gas', 'feesone'): 1,
#  ('feesone', 'of'): 1,
#  ('of', '13'): 1,
#  ('13', 'remaining'): 1,
#  ('remaining', 'copy'): 1,
#  ('copy', 'of'): 2,
#  ('the', 'official'): 1,
#  ('official', 'edition'): 1,
#  ('edition', 'of'): 1,
#  ('the', 'constitutionimage'): 1,
#  ('constitutionimage', 'sothebysas'): 1,
#  ('sothebysas', 'of'): 1,
#  ('of', 'last'): 1,
#  ('last', 'thursday'): 1,
#  ('thursday', 'night'): 1,
#  ('night', 'constitutiondao'): 1,
#  ('constitutiondao', 'found'): 1,
#  ('found', 'i'): 1,
#  ('i', '5262'): 1,
#  ('5262', 'char'): 1,
#  ('char', 'in'): 1,
#  ('in', 'keeping'): 1,
#  ('keeping', 'with'): 1,
#  ('with', 'a'): 2,
#  ('a', 'previous'): 1,
#  ('previous', 'announcement'): 1,
#  ('announcement', 'amc'): 1,
#  ('amc', 'theater'): 1,
#  ('theater', 'now'): 1,
#  ('now', 'accept'): 1,
#  ('accept', 'cryptocurrencies'): 1,
#  ('cryptocurrencies', 'a'): 2,
#  ('a', 'payment'): 1,
#  ('payment', 'for'): 1,
#  ('for', 'online'): 1,
#  ('online', 'purchasesbitcoin'): 1,
#  ('purchasesbitcoin', 'ethereum'): 1,
#  ('ethereum', 'bitcoin'): 1,
#  ('bitcoin', 'cash'): 1,
#  ('cash', 'and'): 1,
#  ('and', 'litecoin'): 1,
#  ('litecoin', 'are'): 1,
#  ('are', 'acceptedpreviously'): 1,
#  ('acceptedpreviously', 'the'): 1,
#  ('the', 'compa'): 1,
#  ('compa', '1036'): 1,
#  ('1036', 'char'): 1,
#  ('char', 'ethereum'): 1,
#  ('ethereum', 'ha'): 2,
#  ('ha', 'been'): 1,
#  ('been', 'on'): 1,
#  ('on', 'a'): 1,
#  ('a', 'tear'): 1,
#  ('tear', 'this'): 1,
#  ('year', 'it'): 1,
#  ('it', 'outperformed'): 1,
#  ('outperformed', 'bitcoin'): 1,
#  ('bitcoin', 'this'): 1,
#  ('year', 'and'): 1,
#  ('and', 'ha'): 1,
#  ('ha', 'hit'): 1,
#  ('hit', 'an'): 1,
#  ('an', 'alltime'): 1,
#  ('alltime', 'high'): 1,
#  ('high', 'ethereum'): 1,
#  ('ha', 'even'): 1,
#  ('even', 'won'): 1,
#  ('won', 'over'): 1,
#  ('over', 'people'): 1,
#  ('people', 'like'): 1,
#  ('like', 'mark'): 1,
#  ('mark', 'cubani'): 1,
#  ('cubani', 'have'): 1,
#  ('have', 'my'): 1,
#  ('my', 'fair'): 1,
#  ('fair', 'share'): 1,
#  ('share', 'of'): 1,
#  ('of', 'bitcoin'): 2,
#  ('bitcoin', 'but'): 1,
#  ('but', 'im'): 1,
#  ('im', 'mor'): 1,
#  ('mor', '10978'): 1,
#  ('10978', 'char'): 1,
#  ('char', 'blockchain'): 1,
#  ('blockchain', 'startup'): 1,
#  ('startup', 'monox'): 1,
#  ('monox', 'finance'): 1,
#  ('finance', 'said'): 1,
#  ('said', 'on'): 1,
#  ('on', 'wednesday'): 1,
#  ('wednesday', 'that'): 1,
#  ('that', 'a'): 1,
#  ('a', 'hacker'): 1,
#  ('hacker', 'stole'): 1,
#  ('stole', '31'): 1,
#  ('31', 'million'): 1,
#  ('million', 'by'): 1,
#  ('by', 'exploiting'): 1,
#  ('exploiting', 'a'): 1,
#  ('a', 'bug'): 1,
#  ('bug', 'in'): 1,
#  ('in', 'software'): 1,
#  ('software', 'the'): 1,
#  ('the', 'service'): 1,
#  ('service', 'us'): 1,
#  ('us', 'to'): 1,
#  ('to', 'draft'): 1,
#  ('draft', 'smart'): 1,
#  ('smart', 'contractsthis'): 1,
#  ('contractsthis', 'story'): 1,
#  ('story', 'originally'): 1,
#  ('originally', 'appeared'): 1,
#  ('appeared', 'on'): 1,
#  ('on', 'ar'): 1,
#  ('ar', 'te'): 1,
#  ('te', '4372'): 1,
#  ('4372', 'char'): 1,
#  ('char', 'on'): 1,
#  ('on', 'monday'): 1,
#  ('monday', 'budweiser'): 1,
#  ('budweiser', 'joined'): 1,
#  ('joined', 'the'): 1,
#  ('the', 'nonfungible'): 1,
#  ('nonfungible', 'token'): 1,
#  ('token', 'craze'): 1,
#  ('craze', 'with'): 1,
#  ('with', 'the'): 2,
#  ('the', 'launch'): 1,
#  ('launch', 'of'): 1,
#  ('of', 'it'): 1,
#  ('it', 'first'): 1,
#  ('first', 'collection'): 1,
#  ('collection', 'of'): 1,
#  ('of', 'unique'): 1,
#  ('unique', 'piece'): 1,
#  ('of', 'digital'): 2,
#  ('digital', 'artdepictions'): 1,
#  ('artdepictions', 'of'): 1,
#  ('of', 'beer'): 1,
#  ('beer', 'can'): 1,
#  ('can', 'that'): 1,
#  ('that', 'sold'): 1,
#  ('sold', 'for'): 1,
#  ('for', 'hundred'): 1,
#  ('hundred', 'of'): 1,
#  ('of', 'dollar'): 1,
#  ('dollar', 'eachdub'): 1,
#  ('eachdub', '1512'): 1,
#  ('1512', 'char'): 1,
#  ('char', 'earlier'): 1,
#  ('earlier', 'this'): 2,
#  ('year', 'nothing'): 1,
#  ('nothing', 'released'): 1,
#  ('released', 'a'): 1,
#  ('a', 'pair'): 1,
#  ('pair', 'of'): 1,
#  ('of', 'relatively'): 1,
#  ('relatively', 'cheap'): 1,
#  ('cheap', '99'): 1,
#  ('99', 'ear'): 1,
#  ('ear', '1'): 3,
#  ('1', 'earbuds'): 3,
#  ('earbuds', 'with'): 1,
#  ('a', 'fun'): 1,
#  ('fun', 'transparent'): 1,
#  ('transparent', 'case'): 1,
#  ('case', 'wireless'): 1,
#  ('wireless', 'charging'): 1,
#  ('charging', 'and'): 1,
#  ('and', 'decent'): 1,
#  ('decent', 'sound'): 1,
#  ('sound', 'quality'): 1,
#  ('quality', 'now'): 1,
#  ('now', 'the'): 1,
#  ('the', 'company'): 1,
#  ('company', 'created'): 1,
#  ('created', 'by'): 1,
#  ('by', 'oneplus'): 1,
#  ('oneplus', 'cofounde'): 1,
#  ('cofounde', '1395'): 1,
#  ('1395', 'char'): 1,
#  ('char', 'nicholas'): 1,
#  ('nicholas', 'merten'): 1,
#  ('merten', 'an'): 1,
#  ('an', 'expert'): 1,
#  ('expert', 'in'): 1,
#  ('in', 'cryptography'): 1,
#  ('cryptography', 'predicts'): 1,
#  ('predicts', 'that'): 1,
#  ('that', 'the'): 1,
#  ('the', 'digital'): 1,
#  ('digital', 'currency'): 1,
#  ('currency', 'ethereum'): 1,
#  ('ethereum', 'will'): 1,
#  ('will', 'overtake'): 1,
#  ('overtake', 'bitcoin'): 1,
#  ('bitcoin', 'in'): 1,
#  ('in', 'the'): 2,
#  ('the', 'market'): 1,
#  ('market', 'after'): 1,
#  ('after', 'reaching'): 1,
#  ('reaching', 'it'): 1,
#  ('it', 'highest'): 1,
#  ('highest', 'value'): 1,
#  ('value', 'since'): 1,
#  ('since', 'may'): 1,
#  ('may', '2018'): 1,
#  ('2018', 'he'): 1,
#  ('he', 'clarified'): 1,
#  ('clarified', 'that'): 1,
#  ('that', 'these'): 1,
#  ('these', 'e'): 1,
#  ('e', '769'): 1,
#  ('769', 'char'): 1,
#  ('char', 'white'): 1,
#  ('white', 'castle'): 2,
#  ('castle', 'double'): 1,
#  ('double', 'cheeseburgererin'): 1,
#  ('cheeseburgererin', 'mcdowellinsiderthe'): 1,
#  ('mcdowellinsiderthe', 'list'): 1,
#  ('list', 'of'): 1,
#  ('of', 'name'): 1,
#  ('name', 'brand'): 1,
#  ('brand', 'getting'): 1,
#  ('getting', 'into'): 1,
#  ('into', 'crypto'): 1,
#  ('crypto', 'growsfast'): 1,
#  ('growsfast', 'food'): 1,
#  ('food', 'chain'): 1,
#  ('chain', 'white'): 1,
#  ('castle', 'announced'): 1,
#  ('announced', 'on'): 1,
#  ('on', 'twitter'): 1,
#  ('twitter', 'that'): 1,
#  ('that', 'it'): 1,
#  ('it', 'registered'): 1,
#  ('registered', 'a'): 1,
#  ('a', 'domain'): 1,
#  ('domain', 'name'): 1,
#  ('name', 'with'): 1,
#  ('with', 'th'): 1,
#  ('th', '1012'): 1,
#  ('1012', 'char'): 1,
#  ('char', 'regal'): 1,
#  ('regal', 'movie'): 1,
#  ('movie', 'theatershutterstockmovietheater'): 1,
#  ('theatershutterstockmovietheater', 'chain'): 1,
#  ('chain', 'regal'): 1,
#  ('regal', 'cinema'): 1,
#  ('cinema', 'is'): 1,
#  ('is', 'the'): 2,
#  ('the', 'latest'): 1,
#  ('latest', 'to'): 1,
#  ('to', 'add'): 1,
#  ('add', 'cryptocurrencies'): 1,
#  ('a', 'a'): 1,
#  ('a', 'form'): 1,
#  ('form', 'paymentthe'): 1,
#  ('paymentthe', 'company'): 1,
#  ('company', 'which'): 1,
#  ('which', 'ha'): 1,
#  ('ha', 'more'): 1,
#  ('than', '500'): 1,
#  ('500', 'theater'): 1,
#  ('theater', 'will'): 1,
#  ('will', 'accept'): 1,
#  ('accept', 'dozen'): 1,
#  ('dozen', 'of'): 1,
#  ('of', 'digi'): 1,
#  ('digi', '1458'): 1,
#  ('1458', 'char'): 1,
#  ('char', 'while'): 1,
#  ('while', 'people'): 1,
#  ('people', 'around'): 1,
#  ('around', 'the'): 1,
#  ('the', 'world'): 2,
#  ('world', 'still'): 1,
#  ('still', 'searched'): 1,
#  ('searched', 'for'): 1,
#  ('for', 'information'): 1,
#  ('information', 'about'): 1,
#  ('about', 'the'): 1,
#  ('the', 'covid19'): 1,
#  ('covid19', 'pandemic'): 1,
#  ('pandemic', 'other'): 1,
#  ('other', 'topic'): 1,
#  ('topic', 'dominated'): 1,
#  ('dominated', 'google'): 1,
#  ('google', 'year'): 1,
#  ('year', 'in'): 2,
#  ('in', 'search'): 1,
#  ('search', 'for'): 1,
#  ('for', '2021'): 1,
#  ('2021', 'like'): 1,
#  ('like', 'cricket'): 1,
#  ('cricket', 'and'): 1,
#  ('and', 'squid'): 1,
#  ('squid', 'game'): 1,
#  ('game', 'match'): 1,
#  ('match', 'for'): 1,
#  ('for', 'the'): 2,
#  ('the', 't20'): 1,
#  ('t20', 'worl'): 1,
#  ('worl', '2053'): 1,
#  ('2053', 'char'): 1,
#  ('char', 'the'): 3,
#  ('the', 'wait'): 1,
#  ('wait', 'is'): 1,
#  ('is', 'finally'): 1,
#  ('finally', 'over'): 1,
#  ('over', 'after'): 1,
#  ('after', 'a'): 1,
#  ('a', 'yearlong'): 1,
#  ('yearlong', 'delay'): 1,
#  ('delay', 'xboxs'): 1,
#  ('xboxs', 'iconic'): 1,
#  ('iconic', 'hero'): 1,
#  ('hero', 'master'): 1,
#  ('master', 'chief'): 1,
#  ('chief', 'is'): 1,
#  ('is', 'back'): 1,
#  ('back', 'with'): 1,
#  ('with', 'halo'): 1,
#  ('halo', 'infinite'): 1,
#  ('infinite', 'there'): 1,
#  ('there', 'are'): 1,
#  ('are', 'new'): 1,
#  ('new', 'toy'): 1,
#  ('toy', 'and'): 1,
#  ('and', 'fight'): 1,
#  ('fight', 'mechanic'): 1,
#  ('mechanic', 'while'): 1,
#  ('while', 'many'): 1,
#  ('many', 'player'): 1,
#  ('player', 'will'): 1,
#  ('will', 'also'): 1,
#  ('also', 'benefit'): 1,
#  ('benefit', 'from'): 1,
#  ('from', 'majo'): 1,
#  ('majo', '4439'): 1,
#  ('4439', 'char'): 1,
#  ('char', 'microstrategy'): 1,
#  ('microstrategy', 'ceo'): 1,
#  ('ceo', 'michael'): 1,
#  ('michael', 'saylorjoe'): 1,
#  ('saylorjoe', 'raedlegetty'): 1,
#  ('raedlegetty', 'imagesullithe'): 1,
#  ('imagesullithe', 'lack'): 1,
#  ('lack', 'of'): 1,
#  ('of', 'a'): 1,
#  ('a', 'spot'): 1,
#  ('spot', 'bitcoin'): 1,
#  ('bitcoin', 'etf'): 1,
#  ('etf', 'mean'): 1,
#  ('mean', 'some'): 1,
#  ('some', 'investor'): 1,
#  ('investor', 'are'): 1,
#  ('are', 'looking'): 1,
#  ('looking', 'for'): 1,
#  ('for', 'other'): 1,
#  ('other', 'way'): 1,
#  ('way', 'to'): 1,
#  ('to', 'gain'): 1,
#  ('gain', 'exposure'): 1,
#  ('exposure', 'to'): 1,
#  ('to', 'cryptocurrenciesliliinvestors'): 1,
#  ('cryptocurrenciesliliinvestors', '2615'): 1,
#  ('2615', 'char'): 1,
#  ('the', 'fine'): 1,
#  ('fine', 'print'): 1,
#  ('print', 'the'): 1,
#  ('the', 'following'): 1,
#  ('following', 'comment'): 1,
#  ('comment', 'are'): 1,
#  ('are', 'owned'): 1,
#  ('owned', 'by'): 1,
#  ('by', 'whoever'): 1,
#  ('whoever', 'posted'): 1,
#  ('posted', 'them'): 1,
#  ('them', 'we'): 1,
#  ('we', 'are'): 1,
#  ('are', 'not'): 1,
#  ('not', 'responsible'): 1,
#  ('responsible', 'for'): 1,
#  ('for', 'them'): 1,
#  ('them', 'in'): 1,
#  ('in', 'any'): 1,
#  ('any', 'way'): 1,
#  ('way', 'available'): 1,
#  ('available', 'for'): 1,
#  ('the', 'same'): 1,
#  ('same', 'price'): 1,
#  ('price', '99'): 1,
#  ('99', 'on'): 1,
#  ('on', 'december'): 1,
#  ('december', '13ththe'): 1,
#  ('13ththe', 'ear'): 1,
#  ('earbuds', 'and'): 1,
#  ('and', 'case'): 1,
#  ('case', 'now'): 1,
#  ('now', 'in'): 1,
#  ('in', 'blackimage'): 1,
#  ('blackimage', 'nothingnothings'): 1,
#  ('nothingnothings', 'ear'): 1,
#  ('earbuds', 'which'): 1,
#  ('which', 'launched'): 1,
#  ('launched', 'earlier'): 1,
#  ('in', 'a'): 1,
#  ('a', 'fetching'): 1,
#  ('fetching', 'white'): 1,
#  ('white', 'and'): 1,
#  ('and', 'transp'): 1,
#  ('transp', '1865'): 1,
#  ('1865', 'char'): 1,
#  ('char', 'bitcoin'): 1,
#  ('bitcoin', 'ha'): 1,
#  ('ha', 'lost'): 2,
#  ('lost', 'almost'): 1,
#  ('almost', '20'): 1,
#  ('20', 'per'): 1,
#  ('per', 'cent'): 1,
#  ('cent', 'in'): 1,
#  ('in', 'le'): 1,
#  ('le', 'than'): 1,
#  ('than', 'two'): 1,
#  ('two', 'week'): 1,
#  ('week', 'proving'): 1,
#  ('proving', 'that'): 1,
#  ('that', 'extreme'): 1,
#  ('extreme', 'volatility'): 1,
#  ('volatility', 'remains'): 1,
#  ('remains', 'a'): 1,
#  ('a', 'hallmark'): 1,
#  ('hallmark', 'of'): 1,
#  ('of', 'crypto'): 1,
#  ('crypto', 'investingyet'): 1,
#  ('investingyet', 'in'): 1,
#  ('world', 'of'): 1,
#  ('bitcoin', 'it'): 1,
#  ('it', 'largely'): 1,
#  ('largely', 'business'): 1,
#  ('business', 'a'): 1,
#  ('a', 'usual'): 1,
#  ('usual', 'with'): 1,
#  ('with', 'b'): 1,
#  ('b', '2054'): 1,
#  ('2054', 'char'): 1,
#  ('char', 'decentralized'): 1,
#  ('decentralized', 'finance'): 2,
#  ('finance', 'or'): 1,
#  ('or', 'defi'): 1,
#  ('defi', 'is'): 1,
#  ('is', 'a'): 1,
#  ('a', 'global'): 1,
#  ('global', 'financial'): 1,
#  ('financial', 'system'): 1,
#  ('system', 'thats'): 1,
#  ('thats', 'available'): 1,
#  ('available', 'on'): 1,
#  ('on', 'blockchains'): 1,
#  ('blockchains', 'that'): 1,
#  ('that', 'are'): 1,
#  ('are', 'public'): 1,
#  ('public', 'most'): 1,
#  ('most', 'often'): 1,
#  ('often', 'ethereumdefi'): 1,
#  ('ethereumdefi', 'stand'): 1,
#  ('stand', 'for'): 2,
#  ('for', 'decentralized'): 1,
#  ('finance', 'in'): 1,
#  ('in', 'simple'): 1,
#  ('simple', 'word'): 1,
#  ('word', 'it'): 1,
#  ('it', 'stand'): 1,
#  ('for', '7096'): 1,
#  ('7096', 'char'): 1,
#  ('the', 'u'): 2,
#  ('u', 'captioning'): 1,
#  ('captioning', 'company'): 1,
#  ('company', 'and'): 1,
#  ('and', 'the'): 1,
#  ('the', 'british'): 1,
#  ('british', 'institute'): 1,
#  ('institute', 'of'): 1,
#  ('of', 'verbatim'): 1,
#  ('verbatim', 'reporter'): 1,
#  ('reporter', 'bivr'): 1,
#  ('bivr', 'recently'): 1,
#  ('recently', 'released'): 1,
#  ('released', 'report'): 1,
#  ('report', 'on'): 1,
#  ('on', 'the'): 1,
#  ('the', 'most'): 2,
#  ('most', 'mispronounced'): 1,
#  ('mispronounced', 'word'): 1,
#  ('word', 'of'): 1,
#  ('the', 'yearthat'): 1,
#  ('yearthat', 'is'): 1,
#  ('most', 'challenging'): 1,
#  ('challenging', 'word'): 1,
#  ('word', 'for'): 1,
#  ('for', 'newsrea'): 1,
#  ('newsrea', '2998'): 1,
#  ('2998', 'char'): 1,
#  ('char', 'image'): 1,
#  ('image', 'source'): 1,
#  ('source', 'getty'): 1,
#  ('getty', 'imagesimage'): 1,
#  ('imagesimage', 'caption'): 1,
#  ('caption', 'the'): 1,
#  ('the', 'group'): 1,
#  ('group', 'had'): 1,
#  ('had', 'hoped'): 1,
#  ('hoped', 'to'): 1,
#  ('to', 'buy'): 2,
#  ('buy', 'the'): 1,
#  ('the', 'copy'): 1,
#  ('copy', 'using'): 1,
#  ('using', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'ethereuma'): 1,
#  ('ethereuma', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'group'): 1,
#  ('group', 'ha'): 1,
#  ('lost', 'in'): 1,
#  ('in', 'it'): 1,
#  ('it', 'effort'): 1,
#  ('effort', 'to'): 1,
#  ('buy', 'a'): 1,
#  ('a', 'rare'): 1,
#  ('rare', 'copy'): 1,
#  ('u', 'constitution'): 1,
#  ('constitution', '1020'): 1,
#  ('1020', 'char'): 1,
#  ('char', 'hour'): 1,
#  ('hour', 'ago'): 1,
#  ('ago', 'a'): 1,
#  ('website', 'appeared'): 1,
#  ('appeared', 'online'): 1,
#  ('online', 'with'): 1,
#  ('the', 'express'): 1,
#  ('express', 'purpose'): 1,
#  ('purpose', 'of'): 1,
#  ('of', 'hosting'): 1,
#  ('hosting', 'a'): 1,
#  ('a', 'nearly'): 1,
#  ('nearly', '20tb'): 1,
#  ('20tb', 'torrent'): 1,
#  ('torrent', 'thats'): 1,
#  ('thats', 'terabyte'): 1,
#  ('terabyte', 'folk'): 1,
#  ('folk', 'the'): 1,
#  ('the', 'big'): 1,
#  ('big', 'boy'): 1,
#  ('boy', 'of'): 1,
#  ('digital', 'data'): 1,
#  ('data', 'measurement'): 1,
#  ('measurement', 'containing'): 1,
#  ('containing', 'every'): 1,
#  ('every', 'nft'): 1,
#  ('nft', 'available'): 1,
#  ('available', 'throug'): 1,
#  ('throug', '2692'): 1,
#  ('2692', 'char'): 1}

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_tokens, 10)
# Out:
# [('a', 39),
#  ('the', 32),
#  ('of', 22),
#  ('bitcoin', 18),
#  ('char', 18),
#  ('to', 15),
#  ('in', 13),
#  ('and', 8),
#  ('on', 8),
#  ('it', 8)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_tokens, 10)
# Out:
# [('the', 29),
#  ('of', 23),
#  ('a', 20),
#  ('char', 19),
#  ('in', 12),
#  ('for', 11),
#  ('on', 9),
#  ('to', 8),
#  ('ha', 8),
#  ('that', 8)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(btc_tokens))
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc2 = WordCloud().generate(' '.join(eth_tokens))
plt.imshow(wc2)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 567 kB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.2.0) (3.2.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: jinja2 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.2)
# Requirement already satisfied: setuptools in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jinhyeongpark/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_NER = btc_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(bitcoin_NER)
doc.ents

# Add a title to the document
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Niagara Falls PERSON
# this month DATE
# Somerset GPE
# N.Y. GPE
# $550 million MONEY
# Terawulf DATE
# 150-megawatt QUANTITY
# this year DATE
# 99 MONEY
# OnePlus ORG
# El Salvador/ GPE
# Reuters ORG
# El Salvador GPE
# first ORDINAL
# Bitcoin City GPE
# $1 billion MONEY
# Nayib Bukele PERSON
# AMC ORG
# first ORDINAL
# El Salvador GPE
# Bitcoin City GPE
# 99 MONEY
# December 13th DATE
# The Ear 1 WORK_OF_ART
# Nothings Ear 1 PERSON
# earlier this year DATE
# Monday DATE
# Florida GPE
# half CARDINAL
# Adele PERSON
# 30 CARDINAL
# +3186 ORG
# 4 CARDINAL
# Reuters ORG
# 8.4% PERCENT
# 49,228.82 MONEY
# 20:01 CARDINAL
# Saturday DATE
# 4,514.87 MONEY
# Bitcoin PERSON
# 28.7% PERCENT
# Baseball League ORG
# Perth Heat PERSON
# first ORDINAL
# Hea PERSON
# fifth ORDINAL
# Saturday DATE
# nearly a billion dollars MONEY
# fifth ORDINAL
# Saturday DATE
# nearly a billion dollars MONEY
# 3 CARDINAL
# Reuters ORG
# 5.5% PERCENT
# 53,435.9 MONEY
# 22:04 CARDINAL
# Friday DATE
# 3,112.06 MONEY
# Bitcoin PERSON
# 22.6% PERCENT
# Bitcoin PERSON
# October 19, 2021 DATE
# REUTERS ORG
# Reuters ORG
# 9.29% PERCENT
# 48,752.15 MONEY
# almost 5% PERCENT
# Monday DATE
# the start of the week DATE
# a bruising weekend DATE
# one CARDINAL
# fifth ORDINAL
# El Salvador GPE
# first ORDINAL
# Bitcoin City GPE
# $1 billion MONEY
# Nayib Bukele PERSON
# CIA ORG
# this week DATE
# Florida GPE
# half CARDINAL
# this week DATE
# Florida GPE
# half CARDINAL
# May 20, 2021 DATE
# REUTERS ORG
# Dado Ruvic/File PhotoLONDON PERSON
# Reuters ORG
# 60 MONEY

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The plant opening northeast of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niagara Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Somerset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N.Y.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is part of a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $550 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  project by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Terawulf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a Bitcoin mining company. The project also includes a proposed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     150-megawatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  … [+1514 chars]Earlier
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Nothing released a pair of relatively cheap $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Ear 1 earbuds with a fun transparent case, wireless charging and decent sound quality. Now, the company (created by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OnePlus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cofounde… [+1395 chars]MIZATA,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador/
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# LONDON, Nov 22 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  plans to build the world's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# &quot; with money from a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  bitcoin-backed bond the country's President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayib Bukele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said o… [+3147 chars]In keeping with a previous announcement,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>After becoming the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country to accept the cryptocurrency as legal tender,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  plans to build the world's first
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , funded initially by bitcoin-backed bonds.Available for the same price, $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     December 13th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Ear 1
#     <span style="font-size: 0.8em

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Somerset', 'N.Y.', 'El Salvador/', 'El Salvador', 'Bitcoin City', 'El Salvador', 'Bitcoin City', 'Florida', 'El Salvador', 'Bitcoin City', 'Florida', 'Florida']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
ethereum_NER = eth_df["text"].str.cat()

# %%
# Run the NER processor on all of the text
doc = nlp(ethereum_NER)
doc.ents

# Add a title to the document
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# this year DATE
# Australian Geoffrey Huntley PERSON
# chars]More than $1.2 million MONEY
# One CARDINAL
# 13 CARDINAL
# the Official Edition of the WORK_OF_ART
# Constitution LAW
# Sothebys GPE
# last Thursday TIME
# night TIME
# ConstitutionDAO PERSON
# AMC ORG
# this year DATE
# this year DATE
# Mark Cuban PERSON
# Wednesday DATE
# $31 million MONEY
# Ars Te ORG
# Monday DATE
# Budweiser ORG
# first ORDINAL
# hundreds of dollars MONEY
# this year DATE
# 99 MONEY
# OnePlus ORG
# Merten PERSON
# May 2018 DATE
# Castle PRODUCT
# Erin McDowell/Insider PERSON
# White Castle FAC
# Twitter PRODUCT
# Shutterstock ORG
# Regal Cinemas PERSON
# more than 500 CARDINAL
# dozens CARDINAL
# Google ORG
# Search GPE
# 2021 DATE
# Squid Game ORG
# year-long DATE
# Xboxs ORG
# Halo Infinite ORG
# Michael SaylorJoe Raedle/Getty Images PERSON
# ETF ORG
# 99 MONEY
# December 13th DATE
# The Ear 1 WORK_OF_ART
# Nothings Ear 1 PERSON
# earlier this year DATE
# less than two weeks DATE
# DeFi GPE
# Ethereum ORG
# DeFi GPE
# the British Institute of Verbatim Reporters ORG
# Getty Images ORG
# Ethereum ORG
# US GPE
# 20 CARDINAL
# NFT ORG

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# </br>In what may be one of the better pieces of performance art
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian Geoffrey Huntley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has created a website that promises to… [+4542
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]More than $1.2 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  remaining copies of
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Official Edition of the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Constitution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# </br>Image:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sothebys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ConstitutionDAO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  found i… [+5262 chars]In keeping with a previous announcement,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Previously, the compa… [+1036 chars]Ethereum has been on a tear
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Its outperformed bitcoin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and has hit an all-time high. Ethereum has even won over people like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Cuban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>I have my fair share of bitcoin, but Im mor… [+10978 chars]Blockchain startup MonoX Finance said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that a hacker stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $31 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>This story originally appeared on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ars Te
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+4372 chars]On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Budweiser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  joined the non-fungible token craze with the launch of its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  collection of unique pieces of digital art  depictions of beer cans that sold for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds of dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Dub… [+1512 chars]Earlier
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Nothing released a pair of relatively cheap $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Sothebys', 'Search', 'DeFi', 'DeFi', 'US']

# %% [markdown]
# ---
